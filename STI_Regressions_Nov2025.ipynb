# %% [markdown]
# STI Rates Data Exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols

# %% [markdown]
# CHLAMYDIA DATA

# %%
chlamydia = pd.read_csv('STI Data/chlamydia.csv')
chlamydia.head(10)
# Out:
#    Rank           State   Cases  Rate_per_100k
# 0     1       Louisiana   36242          792.4
# 1     2     Mississippi   20603          700.9
# 2     3          Alaska    5117          697.7
# 3     4         Alabama   33261          651.1
# 4     5         Georgia   71294          646.4
# 5     6  South Carolina   32889          612.1
# 6     7  North Carolina   65867          607.9
# 7     8        Maryland   35836          579.8
# 8     9        Arkansas   17781          579.6
# 9    10        New York  109284          558.4

# %%
chlamydia.columns
chlamydia.describe()
chlamydia.info()
chlamydia['State'].is_unique
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           50 non-null     int64
#  1   State          50 non-null     object
#  2   Cases          50 non-null     int64
#  3   Rate_per_100k  50 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.7+ KB
# True

# %%
case = chlamydia['Cases']
plt.hist(case)
# Out:
# (array([24., 14.,  5.,  3.,  0.,  2.,  0.,  1.,  0.,  1.]),
#  array([  1307.,  20312.,  39317.,  58322.,  77327.,  96332., 115337.,
#         134342., 153347., 172352., 191357.]),
#  <BarContainer object of 10 artists>)

# %%
rate = chlamydia['Rate_per_100k']
plt.hist(rate)
plt.title("Distribution of Chlamydia Rates")
plt.xlabel("Rate per 100k")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# GONORRHEA

# %%
gonorrhea = pd.read_csv('STI Data/gonorrhea.csv')
gonorrhea.head(10)
# Out:
#    Rank           State  Cases  Rate_per_100k
# 0     1          Alaska   2280          310.9
# 1     2       Louisiana  13192          288.4
# 2     3         Georgia  30307          274.8
# 3     4    South Dakota   2329          253.3
# 4     5     Mississippi   7382          251.1
# 5     6  North Carolina  26353          243.2
# 6     7        New York  46102          235.6
# 7     8         Alabama  11592          226.9
# 8     9  South Carolina  11950          222.4
# 9    10        Maryland  12802          207.1

# %%
gonorrhea.columns
gonorrhea.describe()
gonorrhea.info()
gonorrhea['State'].is_unique
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           50 non-null     int64
#  1   State          50 non-null     object
#  2   Cases          50 non-null     int64
#  3   Rate_per_100k  50 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.7+ KB
# True

# %%
case = gonorrhea['Cases']
plt.hist(case)
# Out:
# (array([27., 13.,  3.,  2.,  1.,  0.,  2.,  1.,  0.,  1.]),
#  array([  220. ,  7608.3, 14996.6, 22384.9, 29773.2, 37161.5, 44549.8,
#         51938.1, 59326.4, 66714.7, 74103. ]),
#  <BarContainer object of 10 artists>)

# %%
rate = gonorrhea['Rate_per_100k']
plt.hist(rate)
plt.title("Distribution of Gonorrhea Rates")
plt.xlabel("Rate per 100k")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# CONGENITAL SYPHILIS

# %%
cong_syph = pd.read_csv('STI Data/congenital_syphilis.csv')
cong_syph.head(10)
# Out:
#    Rank         State  Cases  Rate_per_100k
# 0     1  South Dakota     54          482.1
# 1     2    New Mexico     91          421.0
# 2     3   Mississippi    131          377.8
# 3     4       Arizona    233          296.6
# 4     5         Texas    930          238.6
# 5     6        Nevada     77          232.0
# 6     7     Louisiana    109          193.0
# 7     8      Arkansas     64          180.4
# 8     9       Montana     19          170.0
# 9    10      Oklahoma     79          163.5

# %%
cong_syph.columns
cong_syph.describe()
cong_syph.info()
cong_syph['State'].is_unique
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           48 non-null     int64
#  1   State          48 non-null     object
#  2   Cases          48 non-null     int64
#  3   Rate_per_100k  48 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.6+ KB
# True

# %%
case = cong_syph['Cases']
plt.hist(case)
# Out:
# (array([39.,  5.,  2.,  0.,  0.,  1.,  0.,  0.,  0.,  1.]),
#  array([  1. ,  93.9, 186.8, 279.7, 372.6, 465.5, 558.4, 651.3, 744.2,
#         837.1, 930. ]),
#  <BarContainer object of 10 artists>)

# %%
rate = cong_syph['Rate_per_100k']
plt.hist(rate)
plt.title("Distribution of Congenital Syphilis Rates")
plt.xlabel("Rate per 100k")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# PRIMARY SECONDARY SYPHILIS

# %%
prim_syph = pd.read_csv('STI Data/primary_secondary_syphilis.csv')
prim_syph.head(10)
# Out:
#    Rank         State  Cases  Rate_per_100k
# 0     1  South Dakota    675           73.4
# 1     2    New Mexico    773           36.6
# 2     3   Mississippi    886           30.1
# 3     4      Arkansas    896           29.2
# 4     5       Alabama   1460           28.6
# 5     6      Oklahoma   1121           27.7
# 6     7       Montana    312           27.5
# 7     8     Louisiana   1196           26.1
# 8     9       Arizona   1793           24.1
# 9    10        Nevada    725           22.7

# %%
prim_syph.columns
prim_syph.describe()
prim_syph.info()
prim_syph['State'].is_unique
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           50 non-null     int64
#  1   State          50 non-null     object
#  2   Cases          50 non-null     int64
#  3   Rate_per_100k  50 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.7+ KB
# True

# %%
case = prim_syph['Cases']
plt.hist(case)
# Out:
# (array([20., 18.,  5.,  3.,  1.,  0.,  1.,  1.,  0.,  1.]),
#  array([3.0000e+00, 6.3750e+02, 1.2720e+03, 1.9065e+03, 2.5410e+03,
#         3.1755e+03, 3.8100e+03, 4.4445e+03, 5.0790e+03, 5.7135e+03,
#         6.3480e+03]),
#  <BarContainer object of 10 artists>)

# %%
rate = prim_syph['Rate_per_100k']
plt.hist(rate)
plt.title("Distribution of Primary Secondary Syphilis Rates")
plt.xlabel("Rate per 100k")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# STI Regression

# %%
state = pd.read_csv('newer_US_Sex_ed.csv')
state.head(10)
state = state.rename(columns={'state': 'State'})
state.columns
# Out:
# Index(['State', 'overall_grade', 'sex_ed_requirement_grade', 'content_grade'], dtype='object')

# %% [markdown]
# Chlamydia

# %%
chlamydia.shape
# Out:
# (50, 4)

# %%
state.shape
# Out:
# (50, 4)

# %%
combo_chla = pd.merge(chlamydia, state, on = "State")
combo_chla.shape
# Out:
# (50, 7)

# %%
combo_chla.head(10)
# Out:
#    Rank           State   Cases  Rate_per_100k overall_grade
# 0     1       Louisiana   36242          792.4             f  \
# 1     2     Mississippi   20603          700.9             f
# 2     3          Alaska    5117          697.7             d
# 3     4         Alabama   33261          651.1            c-
# 4     5         Georgia   71294          646.4            d+
# 5     6  South Carolina   32889          612.1            c-
# 6     7  North Carolina   65867          607.9             c
# 7     8        Maryland   35836          579.8             b
# 8     9        Arkansas   17781          579.6             f
# 9    10        New York  109284          558.4             d
#
#   sex_ed_requirement_grade content_grade
# 0                        c             f
# 1                        c             f
# 2                        d             d
# 3                        c            d+
# 4                        a             f
# 5                        a            d-
# 6                        b            c-
# 7                        a            b-
# 8                       f              f
# 9                        c            d-

# %%
model_chlam = ols(formula = 'Rate_per_100k ~ sex_ed_requirement_grade + content_grade', data = combo_chla)
model_chlam = model_chlam.fit()
print( model_chlam.summary() )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Rate_per_100k   R-squared:                       0.368
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     1.320
# Date:                Sun, 30 Nov 2025   Prob (F-statistic):              0.244
# Time:                        17:41:24   Log-Likelihood:                -301.76
# No. Observations:                  50   AIC:                             635.5
# Df Residuals:                      34   BIC:                             666.1
# Df Model:                          15
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                        407.0802     73.170      5.563      0.000     258.380     555.780
# sex_ed_requirement_grade[T.b]   -125.5312     60.369     -2.079      0.045    -248.216      -2.847
# sex_ed_requirement_grade[T.c]     53.3593     55.414      0.963      0.342     -59.255     165.973
# sex_ed_requirement_grade[T.d]    -91.7064     63.252     -1.450      0.156    -220.250      36.837
# sex_ed_requirement_grade[T.f ]   -58.8689     72.161     -0.816      0.420    -205.517      87.779
# content_grade[T.b]                -5.6146    115.079     -0.049      0.961    -239.483     228.253
# content_grade[T.b+]               84.8643     96.882      0.876      0.387    -112.024     281.753
# content_grade[T.b-]              -16.2302    113.459     -0.143      0.887    -246.807     214.347
# content_grade[T.c]               149.3386    121.072      1.233      0.226     -96.709     395.386
# content_grade[T.c ]               28.5198    142.801      0.200      0.843    -261.686     318.726
# content_grade[T.c+]              -75.7599    112.326     -0.674      0.505    -304.033     152.514
# content_grade[T.c-]              251.4386    121.072      2.077      0.045       5.391     497.486
# content_grade[T.d]               171.5433    118.033      1.453      0.155     -68.328     411.414
# content_grade[T.d+]               94.2627     86.864      1.085      0.285     -82.267     270.792
# content_grade[T.d-]               39.7860     90.476      0.440      0.663    -144.083     223.655
# content_grade[T.f]               147.6982     83.585      1.767      0.086     -22.166     317.563
# ==============================================================================
# Omnibus:                        0.990   Durbin-Watson:                   0.873
# Prob(Omnibus):                  0.610   Jarque-Bera (JB):                0.873
# Skew:                           0.013   Prob(JB):                        0.646
# Kurtosis:                       2.353   Cond. No.                         17.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model_chlam = ols(formula = 'Rate_per_100k ~ overall_grade', data = combo_chla)
model_chlam = model_chlam.fit()
print( model_chlam.summary() )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Rate_per_100k   R-squared:                       0.168
# Model:                            OLS   Adj. R-squared:                 -0.016
# Method:                 Least Squares   F-statistic:                    0.9112
# Date:                Sun, 30 Nov 2025   Prob (F-statistic):              0.518
# Time:                        20:47:07   Log-Likelihood:                -279.65
# No. Observations:                  45   AIC:                             577.3
# Df Residuals:                      36   BIC:                             593.6
# Df Model:                           8
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept              394.6949     21.616     18.259      0.000     350.855     438.535
# overall_grade[T.a]     -36.2449     88.223     -0.411      0.684    -215.170     142.680
# overall_grade[T.a- ]  1.266e-14   1.98e-14      0.640      0.526   -2.74e-14    5.28e-14
# overall_grade[T.b+]   -1.06e-14   2.29e-14     -0.462      0.647   -5.71e-14    3.59e-14
# overall_grade[T.b]      10.9051     73.107      0.149      0.882    -137.363     159.173
# overall_grade[T.b-]    -68.1949     88.223     -0.773      0.445    -247.120     110.730
# overall_grade[T.c+]  -3.734e-16   2.19e-14     -0.017      0.986   -4.48e-14     4.4e-14
# overall_grade[T.c]     125.8051     64.229      1.959      0.058      -4.457     256.067
# overall_grade[T.c-]     85.7717     45.750      1.875      0.069      -7.014     178.557
# overall_grade[T.d+]     25.2851     58.255      0.434      0.667     -92.863     143.433
# overall_grade[T.d]     131.5384     73.107      1.799      0.080     -16.730     279.807
# overall_grade[T.d-]     16.1551     64.229      0.252      0.803    -114.107     146.417
# overall_grade[T.f]     103.6743     39.910      2.598      0.014      22.733     184.616
# ==============================================================================
# Omnibus:                        0.084   Durbin-Watson:                   0.242
# Prob(Omnibus):                  0.959   Jarque-Bera (JB):                0.019
# Skew:                           0.019   Prob(JB):                        0.990
# Kurtosis:                       2.906   Cond. No.                     1.14e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.08e-35. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# Gonorrhea

# %%
combo_gon = pd.merge(gonorrhea, state, on = "State")
combo_gon.shape
# Out:
# (50, 7)

# %%
combo_gon.head(10)
# Out:
#    Rank           State  Cases  Rate_per_100k overall_grade
# 0     1          Alaska   2280          310.9             d  \
# 1     2       Louisiana  13192          288.4             f
# 2     3         Georgia  30307          274.8            d+
# 3     4    South Dakota   2329          253.3             f
# 4     5     Mississippi   7382          251.1             f
# 5     6  North Carolina  26353          243.2             c
# 6     7        New York  46102          235.6             d
# 7     8         Alabama  11592          226.9            c-
# 8     9  South Carolina  11950          222.4            c-
# 9    10        Maryland  12802          207.1             b
#
#   sex_ed_requirement_grade content_grade
# 0                        d             d
# 1                        c             f
# 2                        a             f
# 3                        d             f
# 4                        c             f
# 5                        b            c-
# 6                        c            d-
# 7                        c            d+
# 8                        a            d-
# 9                        a            b-

# %%
model_gon = ols(formula = 'Rate_per_100k ~ sex_ed_requirement_grade + content_grade', data = combo_gon)
model_gon = model_gon.fit()
print( model_gon.summary() )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Rate_per_100k   R-squared:                       0.328
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     1.105
# Date:                Sun, 30 Nov 2025   Prob (F-statistic):              0.389
# Time:                        17:41:30   Log-Likelihood:                -270.76
# No. Observations:                  50   AIC:                             573.5
# Df Residuals:                      34   BIC:                             604.1
# Df Model:                          15
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                        139.3098     39.359      3.539      0.001      59.322     219.297
# sex_ed_requirement_grade[T.b]    -51.2624     32.473     -1.579      0.124    -117.256      14.731
# sex_ed_requirement_grade[T.c]     31.1706     29.808      1.046      0.303     -29.406      91.747
# sex_ed_requirement_grade[T.d]    -39.2741     34.024     -1.154      0.256    -108.419      29.871
# sex_ed_requirement_grade[T.f ]   -37.5879     38.816     -0.968      0.340    -116.471      41.296
# content_grade[T.b]               -16.4286     61.902     -0.265      0.792    -142.229     109.372
# content_grade[T.b+]               33.7067     52.114      0.647      0.522     -72.202     139.615
# content_grade[T.b-]              -18.7598     61.031     -0.307      0.760    -142.790     105.270
# content_grade[T.c]                44.3584     65.126      0.681      0.500     -87.993     176.710
# content_grade[T.c ]              -12.6098     76.814     -0.164      0.871    -168.715     143.495
# content_grade[T.c+]              -31.7451     60.421     -0.525      0.603    -154.536      91.046
# content_grade[T.c-]              115.7584     65.126      1.777      0.084     -16.593     248.110
# content_grade[T.d]                92.5420     63.491      1.458      0.154     -36.488     221.571
# content_grade[T.d+]               23.6444     46.725      0.506      0.616     -71.313     118.602
# content_grade[T.d-]                8.8486     48.668      0.182      0.857     -90.057     107.754
# content_grade[T.f]                54.5658     44.961      1.214      0.233     -36.806     145.938
# ==============================================================================
# Omnibus:                        0.475   Durbin-Watson:                   0.629
# Prob(Omnibus):                  0.789   Jarque-Bera (JB):                0.612
# Skew:                          -0.082   Prob(JB):                        0.736
# Kurtosis:                       2.483   Cond. No.                         17.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model_gon = ols(formula = 'Rate_per_100k ~ overall_grade', data = combo_gon)
model_gon = model_gon.fit()
print( model_gon.summary() )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Rate_per_100k   R-squared:                       0.135
# Model:                            OLS   Adj. R-squared:                 -0.086
# Method:                 Least Squares   F-statistic:                    0.6109
# Date:                Sun, 30 Nov 2025   Prob (F-statistic):              0.795
# Time:                        20:47:25   Log-Likelihood:                -277.05
# No. Observations:                  50   AIC:                             576.1
# Df Residuals:                      39   BIC:                             597.1
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept             123.4000     49.385      2.499      0.017      23.509     223.291
# overall_grade[T.a-]    40.1500     60.484      0.664      0.511     -82.191     162.491
# overall_grade[T.b]     -0.1333     63.756     -0.002      0.998    -129.092     128.825
# overall_grade[T.b+]    81.3000     85.538      0.950      0.348     -91.716     254.316
# overall_grade[T.b-]   -37.8500     69.841     -0.542      0.591    -179.117     103.417
# overall_grade[T.c]     55.4750     60.484      0.917      0.365     -66.866     177.816
# overall_grade[T.c-]    37.2000     54.597      0.681      0.500     -73.234     147.634
# overall_grade[T.d]     81.3333     63.756      1.276      0.210     -47.625     210.292
# overall_grade[T.d+]    24.5600     58.433      0.420      0.677     -93.633     142.753
# overall_grade[T.d-]    14.7250     60.484      0.243      0.809    -107.616     137.066
# overall_grade[T.f]     41.3077     53.048      0.779      0.441     -65.992     148.608
# ==============================================================================
# Omnibus:                        0.561   Durbin-Watson:                   0.269
# Prob(Omnibus):                  0.755   Jarque-Bera (JB):                0.458
# Skew:                          -0.226   Prob(JB):                        0.795
# Kurtosis:                       2.874   Cond. No.                         18.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Primary Secondary Syphilis

# %%
combo_prim = pd.merge(prim_syph, state, on = "State")
combo_prim.shape
# Out:
# (50, 7)

# %%
combo_prim.head(10)
# Out:
#    Rank         State  Cases  Rate_per_100k overall_grade
# 0     1  South Dakota    675           73.4             f  \
# 1     2    New Mexico    773           36.6            c-
# 2     3   Mississippi    886           30.1             f
# 3     4      Arkansas    896           29.2             f
# 4     5       Alabama   1460           28.6            c-
# 5     6      Oklahoma   1121           27.7             f
# 6     7       Montana    312           27.5             d
# 7     8     Louisiana   1196           26.1             f
# 8     9       Arizona   1793           24.1             f
# 9    10        Nevada    725           22.7            b+
#
#   sex_ed_requirement_grade content_grade
# 0                        d             f
# 1                        b            d+
# 2                        c             f
# 3                       f              f
# 4                        c            d+
# 5                        c             f
# 6                        b             f
# 7                        c             f
# 8                       f              f
# 9                        c            b+

# %%
model_prim = ols(formula = 'Rate_per_100k ~ sex_ed_requirement_grade + content_grade', data = combo_prim)
model_prim = model_prim.fit()
print( model_prim.summary() )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Rate_per_100k   R-squared:                       0.222
# Model:                            OLS   Adj. R-squared:                 -0.122
# Method:                 Least Squares   F-statistic:                    0.6455
# Date:                Sun, 30 Nov 2025   Prob (F-statistic):              0.816
# Time:                        17:41:37   Log-Likelihood:                -186.08
# No. Observations:                  50   AIC:                             404.2
# Df Residuals:                      34   BIC:                             434.8
# Df Model:                          15
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         16.0849      7.237      2.223      0.033       1.378      30.792
# sex_ed_requirement_grade[T.b]     -0.4353      5.971     -0.073      0.942     -12.569      11.698
# sex_ed_requirement_grade[T.c]      3.8453      5.481      0.702      0.488      -7.292      14.983
# sex_ed_requirement_grade[T.d]      2.2284      6.256      0.356      0.724     -10.485      14.942
# sex_ed_requirement_grade[T.f ]    -2.0293      7.137     -0.284      0.778     -16.533      12.475
# content_grade[T.b]                -9.8172     11.382     -0.863      0.394     -32.947      13.313
# content_grade[T.b+]               -1.7195      9.582     -0.179      0.859     -21.192      17.753
# content_grade[T.b-]               -8.7349     11.221     -0.778      0.442     -31.539      14.070
# content_grade[T.c]                -7.0814     11.974     -0.591      0.558     -31.416      17.253
# content_grade[T.c ]               -3.3849     14.123     -0.240      0.812     -32.087      25.317
# content_grade[T.c+]               -4.6076     11.109     -0.415      0.681     -27.184      17.969
# content_grade[T.c-]                0.4686     11.974      0.039      0.969     -23.866      24.803
# content_grade[T.d]                -3.3218     11.674     -0.285      0.778     -27.046      20.402
# content_grade[T.d+]                1.0457      8.591      0.122      0.904     -16.414      18.505
# content_grade[T.d-]               -7.9407      8.948     -0.887      0.381     -26.126      10.244
# content_grade[T.f]                 4.9723      8.267      0.601      0.552     -11.828      21.772
# ==============================================================================
# Omnibus:                       48.805   Durbin-Watson:                   0.684
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              277.283
# Skew:                           2.403   Prob(JB):                     6.15e-61
# Kurtosis:                      13.488   Cond. No.                         17.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model_prim = ols(formula = 'Rate_per_100k ~ overall_grade', data = combo_prim)
model_prim = model_prim.fit()
print( model_prim.summary() )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Rate_per_100k   R-squared:                       0.174
# Model:                            OLS   Adj. R-squared:                 -0.038
# Method:                 Least Squares   F-statistic:                    0.8224
# Date:                Sun, 30 Nov 2025   Prob (F-statistic):              0.610
# Time:                        20:47:43   Log-Likelihood:                -187.56
# No. Observations:                  50   AIC:                             397.1
# Df Residuals:                      39   BIC:                             418.2
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              20.2500      8.248      2.455      0.019       3.566      36.934
# overall_grade[T.a-]    -9.2000     10.102     -0.911      0.368     -29.633      11.233
# overall_grade[T.b]    -10.0167     10.648     -0.941      0.353     -31.555      11.522
# overall_grade[T.b+]     2.4500     14.286      0.171      0.865     -26.447      31.347
# overall_grade[T.b-]   -11.2500     11.665     -0.964      0.341     -34.844      12.344
# overall_grade[T.c]     -3.2750     10.102     -0.324      0.748     -23.708      17.158
# overall_grade[T.c-]    -3.2611      9.119     -0.358      0.723     -21.706      15.183
# overall_grade[T.d]      1.3500     10.648      0.127      0.900     -20.188      22.888
# overall_grade[T.d+]    -8.1300      9.759     -0.833      0.410     -27.870      11.610
# overall_grade[T.d-]   -10.5750     10.102     -1.047      0.302     -31.008       9.858
# overall_grade[T.f]      1.3654      8.860      0.154      0.878     -16.556      19.286
# ==============================================================================
# Omnibus:                       48.378   Durbin-Watson:                   0.458
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              284.300
# Skew:                           2.350   Prob(JB):                     1.84e-62
# Kurtosis:                      13.695   Cond. No.                         18.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Congenital Syphilis

# %%
cong_syph.shape
# Out:
# (48, 4)

# %%
combo_cong = pd.merge(cong_syph, state, on = "State")
combo_cong.shape
# Out:
# (48, 7)

# %%
combo_cong.head(10)
# Out:
#    Rank         State  Cases  Rate_per_100k overall_grade
# 0     1  South Dakota     54          482.1             f  \
# 1     2    New Mexico     91          421.0            c-
# 2     3   Mississippi    131          377.8             f
# 3     4       Arizona    233          296.6             f
# 4     5         Texas    930          238.6            c-
# 5     6        Nevada     77          232.0            b+
# 6     7     Louisiana    109          193.0             f
# 7     8      Arkansas     64          180.4             f
# 8     9       Montana     19          170.0             d
# 9    10      Oklahoma     79          163.5             f
#
#   sex_ed_requirement_grade content_grade
# 0                        d             f
# 1                        b            d+
# 2                        c             f
# 3                       f              f
# 4                        d            c-
# 5                        c            b+
# 6                        c             f
# 7                       f              f
# 8                        b             f
# 9                        c             f

# %%
model_cong = ols(formula = 'Rate_per_100k ~ sex_ed_requirement_grade + content_grade', data = combo_cong)
model_cong = model_cong.fit()
print( model_cong.summary() )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Rate_per_100k   R-squared:                       0.266
# Model:                            OLS   Adj. R-squared:                 -0.078
# Method:                 Least Squares   F-statistic:                    0.7723
# Date:                Sun, 30 Nov 2025   Prob (F-statistic):              0.696
# Time:                        17:41:43   Log-Likelihood:                -284.11
# No. Observations:                  48   AIC:                             600.2
# Df Residuals:                      32   BIC:                             630.2
# Df Model:                          15
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         49.6268     65.789      0.754      0.456     -84.380     183.634
# sex_ed_requirement_grade[T.b]     26.9566     54.283      0.497      0.623     -83.615     137.528
# sex_ed_requirement_grade[T.c]     73.4197     49.826      1.474      0.150     -28.073     174.912
# sex_ed_requirement_grade[T.d]     55.5608     58.264      0.954      0.347     -63.119     174.240
# sex_ed_requirement_grade[T.f ]    54.7237     64.901      0.843      0.405     -77.476     186.924
# content_grade[T.b]               -49.2051    103.469     -0.476      0.638    -259.964     161.554
# content_grade[T.b+]               30.8390     87.171      0.354      0.726    -146.722     208.400
# content_grade[T.b-]               50.6732    128.394      0.395      0.696    -210.857     312.204
# content_grade[T.c]               -59.0855    109.052     -0.542      0.592    -281.216     163.045
# content_grade[T.c ]               85.5732    128.394      0.666      0.510    -175.957     347.104
# content_grade[T.c+]               -9.9366    100.994     -0.098      0.922    -215.654     195.781
# content_grade[T.c-]               58.0145    109.052      0.532      0.598    -164.116     280.145
# content_grade[T.d]               -46.5170    106.319     -0.438      0.665    -263.082     170.048
# content_grade[T.d+]               29.9441     78.101      0.383      0.704    -129.142     189.031
# content_grade[T.d-]              -71.8674     81.371     -0.883      0.384    -237.614      93.880
# content_grade[T.f]                60.9570     75.244      0.810      0.424     -92.309     214.224
# ==============================================================================
# Omnibus:                       29.823   Durbin-Watson:                   0.532
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               61.168
# Skew:                           1.817   Prob(JB):                     5.22e-14
# Kurtosis:                       7.169   Cond. No.                         17.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model_cong = ols(formula = 'Rate_per_100k ~ overall_grade', data = combo_cong)
model_cong = model_cong.fit()
print( model_cong.summary() )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Rate_per_100k   R-squared:                       0.233
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     1.124
# Date:                Sun, 30 Nov 2025   Prob (F-statistic):              0.371
# Time:                        20:25:14   Log-Likelihood:                -285.16
# No. Observations:                  48   AIC:                             592.3
# Df Residuals:                      37   BIC:                             612.9
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              72.2000     74.106      0.974      0.336     -77.952     222.352
# overall_grade[T.a-]    -6.8500     90.761     -0.075      0.940    -190.748     177.048
# overall_grade[T.b]     18.8500    104.801      0.180      0.858    -193.497     231.197
# overall_grade[T.b+]   159.8000    128.355      1.245      0.221    -100.271     419.871
# overall_grade[T.b-]     3.6500    104.801      0.035      0.972    -208.697     215.997
# overall_grade[T.c]     -1.3750     90.761     -0.015      0.988    -185.273     182.523
# overall_grade[T.c-]    49.5222     81.927      0.604      0.549    -116.477     215.522
# overall_grade[T.d]     30.8000     95.670      0.322      0.749    -163.046     224.646
# overall_grade[T.d+]   -18.0400     87.683     -0.206      0.838    -195.703     159.623
# overall_grade[T.d-]   -47.0000     90.761     -0.518      0.608    -230.898     136.898
# overall_grade[T.f]     98.1500     80.043      1.226      0.228     -64.033     260.333
# ==============================================================================
# Omnibus:                       23.880   Durbin-Watson:                   0.435
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.421
# Skew:                           1.548   Prob(JB):                     2.75e-09
# Kurtosis:                       6.182   Cond. No.                         17.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Bar Chart Comparison

# %% [markdown]
# Chlamydia

# %%
combo_chla.head(10)
# Out:
#    Rank           State   Cases  Rate_per_100k overall_grade
# 0     1       Louisiana   36242          792.4             f  \
# 1     2     Mississippi   20603          700.9             f
# 2     3          Alaska    5117          697.7             d
# 3     4         Alabama   33261          651.1            c-
# 4     5         Georgia   71294          646.4            d+
# 5     6  South Carolina   32889          612.1            c-
# 6     7  North Carolina   65867          607.9             c
# 7     8        Maryland   35836          579.8             b
# 8     9        Arkansas   17781          579.6             f
# 9    10        New York  109284          558.4             d
#
#   sex_ed_requirement_grade content_grade
# 0                        c             f
# 1                        c             f
# 2                        d             d
# 3                        c            d+
# 4                        a             f
# 5                        a            d-
# 6                        b            c-
# 7                        a            b-
# 8                       f              f
# 9                        c            d-

# %%
avg_rates_chla = combo_chla.groupby("sex_ed_requirement_grade")["Rate_per_100k"].mean().sort_index()
avg_rates_chla.plot(kind="bar")

plt.xlabel("Sex Ed Requirement Grade")
plt.ylabel("Average Rate")
plt.title("Chlamydia Average Rate by Policy Score")
plt.show()

# %% [markdown]
# Gonorrhea

# %%
avg_rates_gon = combo_gon.groupby("sex_ed_requirement_grade")["Rate_per_100k"].mean().sort_index()
avg_rates_gon.plot(kind="bar")

plt.xlabel("Sex Ed Requirement Grade")
plt.ylabel("Average Rate")
plt.title("Gonorrhea Average Rate by Policy Score")
plt.show()

# %% [markdown]
# Primary Secondary Syphilis

# %%
avg_rates_prim = combo_prim.groupby("sex_ed_requirement_grade")["Rate_per_100k"].mean().sort_index()
avg_rates_prim.plot(kind="bar")

plt.xlabel("Sex Ed Requirement Grade")
plt.ylabel("Average Rate")
plt.title("Primary Secondary Syphilis Average Rate by Policy Score")
plt.show()

# %% [markdown]
# Congenital Syphilis

# %%
avg_rates_cong = combo_cong.groupby("sex_ed_requirement_grade")["Rate_per_100k"].mean().sort_index()
avg_rates_cong.plot(kind="bar")

plt.xlabel("Sex Ed Requirement Grade")
plt.ylabel("Average Rate")
plt.title("Congenital Syphilis Average Rate by Policy Score")
plt.show()
